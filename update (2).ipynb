# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/drive/MyDrive/Training/299 human activity/train.csv")
df.sample(5)
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject          Activity
# 790            0.311495           0.009546  ...        5           WALKING
# 3961           0.264760           0.073729  ...       19  WALKING_UPSTAIRS
# 4145           0.314266          -0.054812  ...       21  WALKING_UPSTAIRS
# 5303           0.276135          -0.021576  ...       25          STANDING
# 3274           0.284993          -0.011759  ...       17          STANDING
#
# [5 rows x 563 columns]

# %%
df['Activity'].value_counts()
# Out:
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64

# %%
df=df.drop('subject',axis=1)

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df)
# Out:
# Activity: ['STANDING' 'SITTING' 'LAYING' 'WALKING' 'WALKING_DOWNSTAIRS'
#  'WALKING_UPSTAIRS']

# %%
target_columns = ['Activity']
for col in target_columns:
    df[col].replace({'STANDING': 1,'SITTING': 2,'LAYING': 3,'WALKING':4,'WALKING_DOWNSTAIRS':5,'WALKING_UPSTAIRS':6},inplace=True)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isna().sum()
# Out:
# tBodyAcc-mean()-X                       0
# tBodyAcc-mean()-Y                       0
# tBodyAcc-mean()-Z                       0
# tBodyAcc-std()-X                        0
# tBodyAcc-std()-Y                        0
#                                        ..
# angle(tBodyGyroJerkMean,gravityMean)    0
# angle(X,gravityMean)                    0
# angle(Y,gravityMean)                    0
# angle(Z,gravityMean)                    0
# Activity                                0
# Length: 562, dtype: int64

# %%
df.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  angle(Z,gravityMean)     Activity
# count        7352.000000        7352.000000  ...           7352.000000  7352.000000
# mean            0.274488          -0.017695  ...             -0.056515     3.324129
# std             0.070261           0.040811  ...              0.279122     1.683605
# min            -1.000000          -1.000000  ...             -1.000000     1.000000
# 25%             0.262975          -0.024863  ...             -0.143414     2.000000
# 50%             0.277193          -0.017219  ...              0.003181     3.000000
# 75%             0.288461          -0.010783  ...              0.107659     5.000000
# max             1.000000           1.000000  ...              1.000000     6.000000
#
# [8 rows x 562 columns]

# %%
df.corr()
# Out:
#                                       tBodyAcc-mean()-X  ...  Activity
# tBodyAcc-mean()-X                              1.000000  ... -0.026616
# tBodyAcc-mean()-Y                              0.148061  ... -0.074745
# tBodyAcc-mean()-Z                             -0.256952  ... -0.053935
# tBodyAcc-std()-X                               0.000619  ...  0.827579
# tBodyAcc-std()-Y                              -0.021903  ...  0.823665
# ...                                                 ...  ...       ...
# angle(tBodyGyroJerkMean,gravityMean)           0.028844  ...  0.000270
# angle(X,gravityMean)                          -0.035257  ... -0.050553
# angle(Y,gravityMean)                           0.034371  ...  0.234964
# angle(Z,gravityMean)                           0.028242  ...  0.219376
# Activity                                      -0.026616  ...  1.000000
#
# [562 rows x 562 columns]

# %%
x=df.iloc[:,:-1] #remove class atribute

# %%
x
# Out:
#       tBodyAcc-mean()-X  ...  angle(Z,gravityMean)
# 0              0.288585  ...             -0.058627
# 1              0.278419  ...             -0.054317
# 2              0.279653  ...             -0.049118
# 3              0.279174  ...             -0.047663
# 4              0.276629  ...             -0.043892
# ...                 ...  ...                   ...
# 7347           0.299665  ...              0.049819
# 7348           0.273853  ...              0.050053
# 7349           0.273387  ...              0.040811
# 7350           0.289654  ...              0.025339
# 7351           0.351503  ...              0.036695
#
# [7352 rows x 561 columns]

# %%
y=df.iloc[:,561] #set target column

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7347    6
# 7348    6
# 7349    6
# 7350    6
# 7351    6
# Name: Activity, Length: 7352, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rclf=RandomForestClassifier()  #create object

# %%
Rclf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
Rclf.score(xtest,ytest)
# Out:
# 0.9775662814411965

# %%
y_pred=Rclf.predict(xtest)

# %%
import seaborn as sns
sns.set(font_scale = 1.5)
def conf_matrix(y_true, y_preds):
    fig, ax = plt.subplots(figsize = (5,5))
    ax = sns.heatmap(
        confusion_matrix(y_true,y_preds),
        annot=True,
        cbar = False,
        fmt = 'g'
    ) 
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix
conf_matrix(ytest,y_pred)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Clf=DecisionTreeClassifier()

# %%
Clf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
Clf.score(xtest,ytest)
# Out:
# 0.946974847042828

# %%
y_pred=Clf.predict(xtest)

# %%
import seaborn as sns
sns.set(font_scale = 1.5)
def conf_matrix(y_true, y_preds):
    fig, ax = plt.subplots(figsize = (5,5))
    ax = sns.heatmap(
        confusion_matrix(y_true,y_preds),
        annot=True,
        cbar = False,
        fmt = 'g'
    ) 
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

# %%
conf_matrix(ytest,y_pred)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neighbors_settings=range(1,26) #KNN 25 times
for n_neighbors in neighbors_settings:
  knn=KNeighborsClassifier(n_neighbors=n_neighbors)
  knn.fit(xtrain,ytrain)

# %%
knn.score(xtest,ytest)
# Out:
# 0.9503738953093134

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop(['Activity'], axis = 1)
y = df['Activity']

# %%
std = StandardScaler()
X_scaled = std.fit_transform(X)

# %%
X_train_s, X_test_s, y_train, y_test = train_test_split(X_scaled, y)

# %%
lr_stock = LogisticRegression()
lr_stock.fit(X_train_s, y_train)
# Out:
# LogisticRegression()

# %%
lr_stock.score(X_test_s, y_test)
# Out:
# 0.9885745375408053
